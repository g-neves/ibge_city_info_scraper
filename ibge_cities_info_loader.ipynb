# %%
import pandas as pd
pd.set_option('max_columns', None)

cities_info = pd.read_csv("cities_info.csv")
cities_info
# Out:
#               cidade População estimada (pessoas)  \
# 0        sp/campinas                    1.223.237
# 1     sp/santo-andre                      723.889
# 2   mg/montes-claros                      417.478
# 3         mg/uberaba                      340.277
# 4  rj/rio-de-janeiro                    6.775.561
#
#   População no último censo (pessoas) Densidade demográfica (hab/km²)  \
# 0                           1.080.113                        1.359,60
# 1                             676.407                        3.848,01
# 2                             361.915                          101,41
# 3                             295.988                           65,43
# 4                           6.320.446                        5.265,82
#
#   Salário médio mensal dos trabalhadores formais (salários mínimos)  \
# 0                                                3,7
# 1                                                2,7
# 2                                                2,1
# ...
